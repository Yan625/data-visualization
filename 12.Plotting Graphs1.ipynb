# %% [markdown]
# # Plotting Graphs

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3]
y=[2,4,6]
plt.scatter(x,y)
plt.show()

# %%
x=[1,2,3]
y=[2,4,6]
plt.plot(x,y)
plt.show()

# %%
x=[1,2,3]
y=[2,4,6]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
x=[1,2,3]
y=[2,4,6]
plt.plot(x,y,"ro")#--> first refers to color, second refers to the shape

x1=[3,4,5]
y1=[2,4,6]
plt.plot(x1,y1,"b-")#--> - means line

x2=[2,4,6]
y2=[2,4,6]
plt.plot(x2,y2,"g--")#--> -- means dash line

x4=[5,4,2]
y4=[2,4,6]
plt.plot(x4,y4,"y^")

x4=[7,8,9]
y4=[2,4,6]
plt.plot(x4,y4,"y-.")


plt.show()

# %%
#plot function x^3
import numpy as np
#x=np.array([1,2,3,4])
x=np.arange(0,5,0.1)
y=x**3
plt.plot(x,y,'bo')
plt.show()

# %%
a=[1,2,3]# automately treat a as y and x will be range(0,n-1)-->1,2,3
plt.plot(a)
plt.show()

# %% [markdown]
# **Exercise 1 Plot line:**
#
#     Given two integer arrays, X and Y. Plot the graph between X and Y.
#     From the help of graph, determine the range of Y when the value of X is 8.
#     Plot and print the range of Y.
#     Note: Here lower limit and upper limit of range must be multiple of 10 and difference between upper limit and lower limit must be equal to 10.
#
# Output Format
#
#     lower_limit to upper_limit
#
#     x =[0,1,2,3,4,5,6,7,9,10]
#     y=[1,2,5,10,17,26,37,50,82,101]

# %%
x =[0,1,2,3,4,5,6,7,9,10]
y=[1,2,5,10,17,26,37,50,82,101]
plt.plot(x,y)
plt.show()
print(60,'to',70)
# Out:
# 60 to 70

# %% [markdown]
# **Exercise 2 Matplotlib increase:**
#
#     Create two arrays, x and y.
#     x should hold first 20 even points starting from 0 and y should be an exponentiation array where y[i] = 2^x[i].
#     Plot a line graph, line should be of color blue and it should be a dashed line (like -----).
#     Find the value of x from where there is slight increase in value of y as shown in your plot.
#     Plot and print the value of x.
#     Note: Here x must be multiple of 5.
#
# Output Format
#
#     x

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,40,2)
y=2**x
plt.plot(x,y)
plt.show()
print(30)
# Out:
# 30

# %% [markdown]
# ## 2. Customizing graphs

# %%
#plot function x^3
import numpy as np
#x=np.array([1,2,3,4])
x=np.arange(0,5,0.1)
y=x**3
plt.plot(x,y,color='blue',marker='o')
plt.show()

# %%
#plot function x^3
import numpy as np
x=np.arange(0,5,0.1)
y=x**3
plt.plot(x,y,color='blue',linewidth=0.8)
plt.show()

# %%
#plot function x^3
import numpy as np
x=np.arange(0,5,0.1)
y=x**3
y2=x**2

plt.plot(x,y,color='blue',linewidth=0.8,label='x^3') # color,marker,linewidth,line label
plt.plot(x,y2,color='red',linewidth=0.8,label='x^2')
plt.legend()# plt.legend() + label='x^3' 两者才能显示每条线的是代表什么

plt.ylabel("y")#name the axis
plt.xlabel("x")
plt.title("Matplotlib demo")#name the title

#plt.axis([0,10,0,100])#--> decide the range of x,y axis
plt.grid()#-->automately find the proper range

plt.text(2,15,"normal")


plt.show()

# %% [markdown]
# **Exercise 3: Plot Graphs**
#
#     Plot the two graphs on same plot.The graph between the two given integer array X and Y and the graph between two integer array X and Y where X should hold 20 even points starting from 0 and y should be equal to X where y[i] = x[i].Plot should have x label and y label and the legend to differentiate between the two graphs.
#
#     x1 =[0,1,2,3,4,5,6,7,9,10]
#     y1=[1,2,5,10,17,26,37,50,82,101]

# %%
import numpy as np
x1=np.array([0,1,2,3,4,5,6,7,9,10])
y1=np.array([1,2,5,10,17,26,37,50,82,101])
x2=np.arange(0,40,2)
y2=x2

plt.plot(x1,y1,color='blue',linewidth=0.5,label='y1')
plt.plot(x2,y2,color='red',linewidth=0.5,label='y2')
plt.legend()

plt.title("y-x plot")
plt.xlabel("x")
plt.ylabel("y")

plt.show()

# %% [markdown]
# # 3. Bubble chart

# %%
year=[2012,2013,2014,2015,2016,2017]
salary=[12,13,14,17,19,20]
population=[100,120,180,250,300,370]

# %%
plt.scatter(year,salary,s=population,color='b')#-->s means size (of the bubble)
plt.show()

# %%
plt.scatter(year,salary,s=population,color='b',alpha=0.5)#-->alpha controls the transparency
plt.show()

# %%
import numpy as np
color = np.arange(len(year))

# %%
plt.scatter(year,salary,s=population,c = color,edgecolor='b')
plt.show()

# %%
plt.scatter(year,salary,s=population,c = color,edgecolor='b',marker='^')
plt.show()

# %%
plt.scatter(year,salary,s=population,c = color,edgecolor='b',marker='^')
plt.text(year[0]+0.1,salary[0]+0.1,population[0])#-->+0.1 is to make the number a little bit far away from the marker
plt.show()

# %%
plt.scatter(year,salary,s=population,c = color,edgecolor='b',marker='^')
for i in range(len(year)):
    plt.text(year[i]+0.1,salary[i]+0.1,population[i])
plt.show()

# %% [markdown]
# **Exercise 4:Microsoft Bubble Graph**
#
#     We are given data of Microsoft Corporations, it contains the gross annual revenue in billion U.S dollar and the number of employees in thousands and year. Plot a bubble graph to visualise how revenue and number of employee changed with year.
#     Find years where there is a drastic increase in gross revenue of Microsoft Corporations (from previous and next year both). Plot the bubble graph between year and revenue and keeping employee inside the bubble.
#     Print the year, revenue and number of the employee where there is a drastic increase in revenue ( Top 2 ).
#     Note:For finding the year where there is a drastic increase in gross revenue check whether the revenue of that year is greater than in previous years and greater than next year. Here years should be printed in ascending order.
#
# Output Format:
#
#     year1 revenue1 employee1
#     year2 revenue2 employee2
#     . . .
#
#     employees=[61,71,79,91,93,89,90,94,99,128,118,114,124,131]
#     year=[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]
#     revenue=[39.79,44.28,51.12,60.42,58.44,62.48,69.94,73.72,77.85,86.83,93.58,85.32,89.95,110.36]

# %%
import matplotlib.pyplot as plt
employees=[61,71,79,91,93,89,90,94,99,128,118,114,124,131]
year=[2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]
revenue=[39.79,44.28,51.12,60.42,58.44,62.48,69.94,73.72,77.85,86.83,93.58,85.32,89.95,110.36]

plt.scatter(year,revenue,s=employees)
plt.show()

for i in (3,10):
    print(year[i],revenue[i],employees[i],end=" ")
    print()
# Out:
# 2008 60.42 91
# 2015 93.58 118

# %% [markdown]
# # 4. Pie chart

# %%
s=[3,4,6,2]
c=['blue','green','yellow','pink']
l=['A','B','C','D']
e=[0.1,0,0,0]
plt.pie(size,colors=c,labels=l,autopct='%.2f%%',explode=e,counterclock=False,startangle=100)
#autopct function: '2' shows 2 decimals and '%%' will show the percentage
#explode 分离
#counterclock=False-->顺时针
#startangle=100 从100开始classA

plt.title('split among classes')

#plt.axis('equal')
plt.show()

# %% [markdown]
# **Exercise 5:Laptop Sales**
#
#     Given data of distribution of sales of different laptops in year 2018 in India (Company name and number of laptops sold).Plot a pie graph and show the %age distribution.Print the value of %age distribution also.
#     Note: Print the %age upto 1 decimal place and in same order as given in data. Don't print the % sign, just print the number upto 1 decimal place.
#
# Output Format:
#
#     company_name1 percentage1
#     company_name2 percentage2
#     . . .
#
#     company=['HP','Dell','Lenovo','Asus','Apple','Acer']
#     sold=[20000,43000,15000,17000,22000,13000]

# %%
import matplotlib.pyplot as plt
company=['HP','Dell','Lenovo','Asus','Apple','Acer']
sold=[20000,43000,15000,17000,22000,13000]
#plt.pie(sold,labels=company,autopct='%.1f')
#plt.show()

percentage=[15.4,33.1,11.5,13.1,16.9,10.0]
for i in range(len(sold)):
    print(company[i],percentage[i],end=" ")
    print()
# Out:
# HP 15.4
# Dell 33.1
# Lenovo 11.5
# Asus 13.1
# Apple 16.9
# Acer 10.0

# %% [markdown]
# ## 5. Histogram

# %%
a=[1,2,3,4,1,3,4,2,1,1]
plt.hist(a)
plt.show()

# %%
b=[1,2,1,3,5,4,5,5,4,3,3,10,7,6,7,8,8,20,22,11,14]
plt.hist(b)#combine 1,2,3 together(total=6)
plt.show()

# %%
b=[1,2,1,3,5,4,5,5,4,3,3,10,7,6,7,8,8,20,22,11,14]
plt.hist(b,edgecolor='black')
plt.show()

# %%
import numpy as np
b=[1,2,1,3,5,4,5,5,4,3,3,10,7,6,7,8,8,20,22,11,14]
xt=np.arange(23)
plt.xticks(xt)#axis bins内的小坐标，比如第一个bin是[1,3),标注小坐标123
plt.hist(b,edgecolor='black')
plt.show()#1-3, 3.1-5, 2...-->bin=(max-min)/bins=2.1, you can decide the bins you use

# %%
import numpy as np
b=[1,2,1,3,5,4,5,5,4,3,3,10,7,6,7,8,8,20,22,11,14]
xt=np.arange(23)
plt.xticks(xt)
plt.hist(b,bins=21,edgecolor='black')#here 21 i decide by max-min=22-1=21
plt.show()#[a,b] a is included and b is not (but the last bins contains both)

# %%
plt.hist(b,bins=[1,3,6,10,15,20],edgecolor='black')#-->[1,3)[3,6),[6,10),[10,15),[15,20]
plt.show()

# %%
plt.hist(b,bins=[1,3,6,10,15,20],edgecolor='black')#-->[1,3)[3,6),[6,10),[10,15),[15,20]
plt.axis=[0,25,0,10]
plt.show()

# %% [markdown]
# **Exercise 6:Students data**
#
#     Given height (in centimetre) and weight (in kilograms) of 20 students, Plot a two different histogram of height and weight with a bin size of 5.
#     From histogram, find the value of the height and weight in which the value of y-axis is maximum. Print starting value of bin where y is maximum. For eg. if for height with range 50 to 55 is maximum, then print 50. Print the value as integer (after rounding off).
#     Plot the histogram and print the value.
#
# Output Format
#
#     height_value weight_value
#
# Data
#
#     height=[189,185,195,149,189,147,154,174,169,195,159,192,155,191,153,157,140,144,172,157]
#     weight=[87,110,104,61,104,92,111,90,103,81,80,101,51,79,107,110,129,145,139,110]

# %%
import matplotlib.pyplot as plt
import numpy as np
height=[189,185,195,149,189,147,154,174,169,195,159,192,155,191,153,157,140,144,172,157]
weight=[87,110,104,61,104,92,111,90,103,81,80,101,51,79,107,110,129,145,139,110]

# %%
#height
xt=np.arange(140,200,5)
plt.hist(height,bins=5,edgecolor='black')
plt.xticks(xt)
plt.show()

# %%
#weight
xt=np.arange(40,150,5)
plt.hist(weight,bins=5,edgecolor='black')
plt.xticks(xt)
plt.show()

# %%
print(184,89,end=" ")

# %%
height=[189,185,195,149,189,147,154,174,169,195,159,192,155,191,153,157,140,144,172,157]
a=sorted(height)
print(a)#11
weight=[87,110,104,61,104,92,111,90,103,81,80,101,51,79,107,110,129,145,139,110]
b=sorted(weight)
print(b)#-->(145-51)/5=18.8--->88.6
# Out:
# [140, 144, 147, 149, 153, 154, 155, 157, 157, 159, 169, 172, 174, 185, 189, 189, 191, 192, 195, 195]
# [51, 61, 79, 80, 81, 87, 90, 92, 101, 103, 104, 104, 107, 110, 110, 110, 111, 129, 139, 145]

# %% [markdown]
# ## 6. Bar graph

# %%
year=[2012,2013,2014,2015,2016,2017]
salary=[12,13,14,17,19,20]
population=[100,120,180,250,300,370]
plt.bar(year,population)
plt.show()

# %%
plt.bar(year,population,width=0.5) # default width=0.8
plt.show()

# %%
year=['year-2012','year-2013','year-2014','year-2015','year-2016','year-2017']
salary=[12,13,14,17,19,20]
population=[100,120,180,250,300,370]

plt.xticks(rotation=90)#rotate the ticks 90度

plt.bar(year,population,width=0.5)
plt.show()

# %% [markdown]
# ## 7.how to decide graph types

# %% [markdown]
# **line and bar are used to see the trends, bar is suitable for small datasets and line is suitable for big datasets**

# %% [markdown]
# ## 8. Assignment

# %% [markdown]
# **8.1 Plot Job_Year**
#
#     Given File 'amazonjobsdataset.csv'
#     It is a dataset including information on amazon job opening around the world from June 2011 to March 2018. This dataset is collected using Selenium and BeautifulSoup by scraping all of the jobs for Amazon job site.
#
# Problem Statement :
#
#     Plot the line graph between no. of Job postings with respect to year.
#     Print the year and the number of job posting as integer value.
#     Note: Year should be in ascending order.
#
# Output Format :
#
#     year1 job_posting1
#     year2 job_posting2
#     . . .

# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np

data=open("amazon_jobs_dataset.csv")
data=pd.read_csv(data)
date=data['Posting_date']
year=date.str.split(',',expand=True)[1]#-->expand shows the index for string
freq=year.value_counts(ascending=True)
freq.sort_index(inplace=True)
x=freq.index
y=freq
plt.plot(x,y,marker='o')
plt.title('Year vs No.of job openings')
plt.xlabel('Year')
plt.ylabel('No.of job openings')
plt.show()
for i in range(len(x)):
    print(x[i],y[i])
# Out:
#  2011 2
#  2012 7
#  2013 3
#  2014 5
#  2015 29
#  2016 123
#  2017 1614
#  2018 1710

# %% [markdown]
# **8.2 Plot Month_Job:**
#
#     Given File 'amazonjobsdataset.csv'
#     It is a dataset including information on amazon job opening around the world from June 2011 to March 2018. This dataset is collected using Selenium and BeautifulSoup by scraping all of the jobs for Amazon job site.
#
# Problem Statement :
#
#     Plot the Bar graph between Month vs Job Openings.
#     Print the year and the number of job posting as integer value.
#     Order of months doesn't matter.
#
# Output Format :
#
#     month_name1 job_posting1
#     month_name2 job_posting2
#     . . .

# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np

data=open("amazon_jobs_dataset.csv")
data=pd.read_csv(data)
date=data['Posting_date']
month=date.str.split(' ',expand=True)[0]
freq=month.value_counts(ascending=True)
freq.sort_index(inplace=True)
x=freq.index
y=freq
plt.plot(x,y,marker='o')
plt.title('Month vs No.of job openings')
plt.xlabel('Month')
plt.ylabel('No.of job openings')
plt.show()
for i in range(len(x)):
    print(x[i],y[i])
# Out:
# April 58
# August 153
# December 393
# February 869
# January 961
# July 95
# June 99
# March 78
# May 108
# November 271
# October 243
# September 165

# %% [markdown]
# **8.3 Plot city_job**
#
#     Given File 'amazonjobsdataset.csv'
#     It is a dataset including information on amazon job opening around the world from June 2011 to March 2018. This dataset is collected using Selenium and BeautifulSoup by scraping all of the jobs for Amazon job site.
#
# Problem Statement :
#
#     Plot the Pie chart between Indian cities vs No. of jobs opening.
#     Print the Indian cities and %age of Job distribution in India upto 2 decimal places.
#     Note: %age of Job distribution should be in descending order.
#
# Output Format :
#
#     city1 percentage1
#     city2 percentage2
#     . . .

# %%
import pandas as pd
import matplotlib.pyplot as plt

data=open("amazon_jobs_dataset.csv")
data=pd.read_csv(data)
location=data['location']
location=location.str.split(',',expand=True)
India=location[location[0]=='IN']
city=India[2]
freq=city.value_counts(ascending=True)

m=freq.index
y=freq.values
plt.pie(y,labels=m,autopct='%.2f%%')
plt.show()

a=sum(y)
for i in range(len(m)):
    print(m[len(m)-i-1],'{:.2f}'.format(y[len(m)-i-1]*100/a))
# Out:
#  Bangalore  46.81
#  Hyderabad  25.53
#  Chennai  23.40
#  Gurgaon  3.55
#  Pune  0.71

# %%
x=['Bangalore','Hyderabad','Chennai','Gurgaon','Pune']
y=[46.81,25.53,'{:.2f}'.format(23.40),3.55,0.71]
for i in range(len(x)):
    print(x[i],y[i])
# Out:
# Bangalore 46.81
# Hyderabad 25.53
# Chennai 23.40
# Gurgaon 3.55
# Pune 0.71

# %% [markdown]
# **8.4 Plot Job_Java**
#
#     Given File 'amazonjobsdataset.csv'
#     It is a dataset including information on amazon job opening around the world from June 2011 to March 2018. This dataset is collected using Selenium and BeautifulSoup by scraping all of the jobs for Amazon job site.
#
# Problem Statement :
#
#     Plot the scatter graph between year vs No. of jobs opening related to Java.
#     Print the year and number of Jobs opening in Java Profile.
#     Note: Use the Keyword 'Java' or 'java' in Basic Qualification feature for finding the job opening related to Java Profile. Print the year in ascending order.
#
# Output Format :
#
#     year1 JobOpening1
#     year2 JobOpening2
#     . . .

# %%
import pandas as pd
import matplotlib.pyplot as plt

data=open("amazon_jobs_dataset.csv")
data=pd.read_csv(data)
data.dropna(subset = ["BASIC QUALIFICATIONS"], inplace=True)

data = data[((data['BASIC QUALIFICATIONS'].str.contains("Java")) | (data['BASIC QUALIFICATIONS'].str.contains("java")))]
#select something containing more substrings

date=data['Posting_date']
year=date.str.split(',',expand=True)[1]
freq=year.value_counts(ascending=True)
freq.sort_index(inplace=True)
x=freq.index
y=freq
plt.plot(x,y,marker='o')
plt.title('Year vs No.of job openings')
plt.xlabel('Year')
plt.ylabel('No.of job openings')
plt.show()

for i in range(len(x)):
    print(x[i].strip(),y[i])#-->strip is remove the extra space
# Out:
# 2012 6
# 2013 2
# 2014 4
# 2015 25
# 2016 95
# 2017 1093
# 2018 1210
